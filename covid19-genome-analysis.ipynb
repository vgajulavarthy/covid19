# %%
# !pip install chembl_webresource_client py3Dmol biopython
# !conda install -c conda-forge rdkit --yes
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl-webresource-client-0.10.1.tar.gz (53 kB)
#      |████████████████████████████████| 53 kB 746 kB/s
# Collecting py3Dmol
#   Downloading py3Dmol-0.8.0-py2.py3-none-any.whl (6.7 kB)
# Requirement already satisfied: biopython in /opt/conda/lib/python3.6/site-packages (1.76)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.6/site-packages (from chembl_webresource_client) (1.24.3)
# Requirement already satisfied: requests>=2.18.4 in /opt/conda/lib/python3.6/site-packages (from chembl_webresource_client) (2.22.0)
# Collecting requests-cache>=0.4.7
#   Downloading requests_cache-0.5.2-py2.py3-none-any.whl (22 kB)
# Collecting easydict
#   Downloading easydict-1.9.tar.gz (6.4 kB)
# Requirement already satisfied: jupyter in /opt/conda/lib/python3.6/site-packages (from py3Dmol) (1.0.0)
# Collecting idisplay
#   Downloading idisplay-0.1.2-py2.py3-none-any.whl (4.5 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.6/site-packages (from biopython) (1.18.2)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests>=2.18.4->chembl_webresource_client) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests>=2.18.4->chembl_webresource_client) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests>=2.18.4->chembl_webresource_client) (2019.11.28)
# Requirement already satisfied: notebook in /opt/conda/lib/python3.6/site-packages (from jupyter->py3Dmol) (5.5.0)
# Requirement already satisfied: qtconsole in /opt/conda/lib/python3.6/site-packages (from jupyter->py3Dmol) (4.7.2)
# Requirement already satisfied: ipykernel in /opt/conda/lib/python3.6/site-packages (from jupyter->py3Dmol) (5.1.1)
# Requirement already satisfied: nbconvert in /opt/conda/lib/python3.6/site-packages (from jupyter->py3Dmol) (5.6.1)
# Requirement already satisfied: ipywidgets in /opt/conda/lib/python3.6/site-packages (from jupyter->py3Dmol) (7.5.1)
# Requirement already satisfied: jupyter-console in /opt/conda/lib/python3.6/site-packages (from jupyter->py3Dmol) (6.1.0)
# Requirement already satisfied: ipython>=1.0 in /opt/conda/lib/python3.6/site-packages (from idisplay->py3Dmol) (7.13.0)
# Requirement already satisfied: pyzmq>=17 in /opt/conda/lib/python3.6/site-packages (from notebook->jupyter->py3Dmol) (18.1.1)
# Requirement already satisfied: ipython-genutils in /opt/conda/lib/python3.6/site-packages (from notebook->jupyter->py3Dmol) (0.2.0)
# Requirement already satisfied: terminado>=0.8.1 in /opt/conda/lib/python3.6/site-packages (from notebook->jupyter->py3Dmol) (0.8.3)
# Requirement already satisfied: traitlets>=4.2.1 in /opt/conda/lib/python3.6/site-packages (from notebook->jupyter->py3Dmol) (4.3.3)
# Requirement already satisfied: Send2Trash in /opt/conda/lib/python3.6/site-packages (from notebook->jupyter->py3Dmol) (1.5.0)
# Requirement already satisfied: jupyter-client>=5.2.0 in /opt/conda/lib/python3.6/site-packages (from notebook->jupyter->py3Dmol) (6.1.2)
# Requirement already satisfied: jupyter-core>=4.4.0 in /opt/conda/lib/python3.6/site-packages (from notebook->jupyter->py3Dmol) (4.6.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.6/site-packages (from notebook->jupyter->py3Dmol) (2.11.1)
# Requirement already satisfied: tornado>=4 in /opt/conda/lib/python3.6/site-packages (from notebook->jupyter->py3Dmol) (5.0.2)
# Requirement already satisfied: nbformat in /opt/conda/lib/python3.6/site-packages (from notebook->jupyter->py3Dmol) (5.0.4)
# Requirement already satisfied: qtpy in /opt/conda/lib/python3.6/site-packages (from qtconsole->jupyter->py3Dmol) (1.9.0)
# Requirement already satisfied: pygments in /opt/conda/lib/python3.6/site-packages (from qtconsole->jupyter->py3Dmol) (2.6.1)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.6/site-packages (from nbconvert->jupyter->py3Dmol) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/lib/python3.6/site-packages (from nbconvert->jupyter->py3Dmol) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.6/site-packages (from nbconvert->jupyter->py3Dmol) (1.4.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /opt/conda/lib/python3.6/site-packages (from nbconvert->jupyter->py3Dmol) (0.3)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.6/site-packages (from nbconvert->jupyter->py3Dmol) (3.1.0)
# Requirement already satisfied: testpath in /opt/conda/lib/python3.6/site-packages (from nbconvert->jupyter->py3Dmol) (0.4.4)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /opt/conda/lib/python3.6/site-packages (from ipywidgets->jupyter->py3Dmol) (3.5.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/conda/lib/python3.6/site-packages (from jupyter-console->jupyter->py3Dmol) (3.0.4)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.6/site-packages (from ipython>=1.0->idisplay->py3Dmol) (0.1.0)
# Requirement already satisfied: jedi>=0.10 in /opt/conda/lib/python3.6/site-packages (from ipython>=1.0->idisplay->py3Dmol) (0.15.2)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.6/site-packages (from ipython>=1.0->idisplay->py3Dmol) (4.4.2)
# Requirement already satisfied: setuptools>=18.5 in /opt/conda/lib/python3.6/site-packages (from ipython>=1.0->idisplay->py3Dmol) (46.1.3.post20200330)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.6/site-packages (from ipython>=1.0->idisplay->py3Dmol) (0.7.5)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /opt/conda/lib/python3.6/site-packages (from ipython>=1.0->idisplay->py3Dmol) (4.8.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.6/site-packages (from traitlets>=4.2.1->notebook->jupyter->py3Dmol) (1.14.0)
# Requirement already satisfied: python-dateutil>=2.1 in /opt/conda/lib/python3.6/site-packages (from jupyter-client>=5.2.0->notebook->jupyter->py3Dmol) (2.8.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.6/site-packages (from jinja2->notebook->jupyter->py3Dmol) (1.1.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/conda/lib/python3.6/site-packages (from nbformat->notebook->jupyter->py3Dmol) (3.2.0)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.6/site-packages (from bleach->nbconvert->jupyter->py3Dmol) (0.5.1)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.6/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter->py3Dmol) (0.1.9)
# Requirement already satisfied: parso>=0.5.2 in /opt/conda/lib/python3.6/site-packages (from jedi>=0.10->ipython>=1.0->idisplay->py3Dmol) (0.5.2)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.6/site-packages (from pexpect; sys_platform != "win32"->ipython>=1.0->idisplay->py3Dmol) (0.6.0)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook->jupyter->py3Dmol) (19.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/conda/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook->jupyter->py3Dmol) (0.16.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /opt/conda/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook->jupyter->py3Dmol) (1.5.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat->notebook->jupyter->py3Dmol) (2.2.0)
# Building wheels for collected packages: chembl-webresource-client, easydict
# done
#   Created wheel for chembl-webresource-client: filename=chembl_webresource_client-0.10.1-py3-none-any.whl size=57152 sha256=e58e291ff5e9cfa2e70cb02faaca09bf9821a0dd0d7002b49effb86ed92304a1
#   Stored in directory: /root/.cache/pip/wheels/3f/e6/16/c0a01f0cdc0ad55a4c5f271fe86ce042d33fd59174e089a989
# done
#   Created wheel for easydict: filename=easydict-1.9-py3-none-any.whl size=6349 sha256=ef5d86ed0c7b2687eb1c664d5566c045dc60a929e92ff3b126984a0c348f28cc
#   Stored in directory: /root/.cache/pip/wheels/5d/79/e4/4e55effe206295359b37e0f9db3e68a1197ba396682807dadb
# Successfully built chembl-webresource-client easydict
# Installing collected packages: requests-cache, easydict, chembl-webresource-client, idisplay, py3Dmol
# Successfully installed chembl-webresource-client-0.10.1 easydict-1.9 idisplay-0.1.2 py3Dmol-0.8.0 requests-cache-0.5.2
# done
# done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - rdkit
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     boost-1.72.0               |   py36h9de70de_0         339 KB  conda-forge
#     boost-cpp-1.72.0           |       h8e57a91_0        21.8 MB  conda-forge
#     bzip2-1.0.8                |       h516909a_2         396 KB  conda-forge
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     certifi-2019.11.28         |   py36h9f0ad1d_1         149 KB  conda-forge
#     conda-4.8.3                |   py36h9f0ad1d_1         3.0 MB  conda-forge
#     openssl-1.0.2u             |       h516909a_0         3.2 MB  conda-forge
#     rdkit-2019.09.3            |   py36he9dd633_1        23.7 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        52.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   boost              conda-forge/linux-64::boost-1.72.0-py36h9de70de_0
#   boost-cpp          conda-forge/linux-64::boost-cpp-1.72.0-h8e57a91_0
#   rdkit              conda-forge/linux-64::rdkit-2019.09.3-py36he9dd633_1
#
# The following packages will be UPDATED:
#
#   bzip2                   pkgs/main::bzip2-1.0.6-h14c3975_5 --> conda-forge::bzip2-1.0.8-h516909a_2
#   conda                        anaconda::conda-4.8.3-py36_0 --> conda-forge::conda-4.8.3-py36h9f0ad1d_1
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates      anaconda::ca-certificates-2020.1.1-0 --> conda-forge::ca-certificates-2019.11.28-hecc5488_0
#   certifi               anaconda::certifi-2019.11.28-py36_1 --> conda-forge::certifi-2019.11.28-py36h9f0ad1d_1
#   openssl               anaconda::openssl-1.0.2u-h7b6447c_0 --> conda-forge::openssl-1.0.2u-h516909a_0
#
#
#
# Downloading and Extracting Packages
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# certifi-2019.11.28   | 149 KB    | ##################################### | 100%
# openssl-1.0.2u       | 3.2 MB    | ##################################### | 100%
# boost-cpp-1.72.0     | 21.8 MB   | ##################################### | 100%
# conda-4.8.3          | 3.0 MB    | ##################################### | 100%
# bzip2-1.0.8          | 396 KB    | ##################################### | 100%
# boost-1.72.0         | 339 KB    | ##################################### | 100%
# rdkit-2019.09.3      | 23.7 MB   | ##################################### | 100%
# done
# done
# done

# %%
import Bio
import operator
from Bio.Seq import Seq
from Bio.Alphabet import generic_dna, generic_protein, generic_rna
from Bio.Blast import NCBIWWW
from Bio.SeqUtils.ProtParam import ProteinAnalysis
from Bio import SeqIO
from Bio import pairwise2
from chembl_webresource_client.new_client import new_client

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import py3Dmol

from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem import AllChem

amino_acids_mapping = {v: k for k, v in Bio.SeqUtils.IUPACData.protein_letters_3to1.items()}
# Out:
# RDKit WARNING: [03:20:40] Enabling RDKit 2019.09.3 jupyter extensions

# %%
# Read DNA data
cov2 = SeqIO.read('/kaggle/input/dnasequences/cov2.fasta', "fasta")
sars = SeqIO.read('/kaggle/input/dnasequences/sars.fasta', "fasta")
mers = SeqIO.read('/kaggle/input/dnasequences/mers.fasta', "fasta")

# %%
print(f"Cov2 DNA length: {len(cov2)}")
print(f"Sars DNA length: {len(sars)}")
print(f"Mers DNA length: {len(mers)}")
# Out:
# Cov2 DNA length: 29903
# Sars DNA length: 29751
# Mers DNA length: 30119

# %%
SARS_COV = pairwise2.align.globalxx(sars.seq, cov2.seq, one_alignment_only=True, score_only=True)
MERS_COV = pairwise2.align.globalxx(mers.seq, cov2.seq, one_alignment_only=True, score_only=True)
MERS_SARS = pairwise2.align.globalxx(mers.seq, sars.seq, one_alignment_only=True, score_only=True)

X = ['Sars-Cov2', 'Mers-Cov2', 'Mers-Sars']
Y = [SARS_COV/ len(sars.seq) * 100, MERS_COV/ len(mers.seq)*100, MERS_SARS/len(sars.seq)*100]

# %%
def transcribe(DNA):
    return DNA.transcribe()

# %%
def RNA_to_DNA(RNA):
    if 'Bio.Seq.Seq' not in str(type(RNA)):
        RNA = Seq(RNA, generic_rna)
        
    return RNA.back_transcribe()

# %%
# Get all proteins that contain more than 20 amino acids from an RNA messenger
def get_amino_acids(mRNA):
    proteins = mRNA.translate()
    amino_acids = ''
    
    for protein in proteins.split('*'):
        if len(protein) > 20:
            amino_acids += protein + '*'
            
    return amino_acids

# %%
# Convert DNA's to RNA's
cov2 = transcribe(cov2.seq)
sars = transcribe(sars.seq)
mers = transcribe(mers.seq)

# %%
# Get all amino acids
cov2_acids = get_amino_acids(cov2)
sars_acids = get_amino_acids(sars)
mers_acids = get_amino_acids(mers)
# Out:
# /opt/conda/lib/python3.6/site-packages/Bio/Seq.py:2859: BiopythonWarning: Partial codon, len(sequence) not a multiple of three. Explicitly trim the sequence or add trailing N before translation. This may become an error in future.
#   BiopythonWarning,

# %%
def update_table(t, l):
    for k in l:
        if k in t:
            t[k] += l[k]
        else:
            t[k] = l[k]
    return t

# %%
def get_acid_counter(seq):
    counter = {}

    for protein in seq.split('*'):
        X = ProteinAnalysis(str(protein))
        POI = X.count_amino_acids()
        counter = update_table(counter, POI)
        
    return counter, sorted(counter, key=counter.get, reverse=True)[:4]

# %%
cov2_protein_counter, cov2_protein_highest = get_acid_counter(cov2_acids)

# %%
plt.figure(figsize=(8,4));
plt.bar(cov2_protein_counter.keys(), list(cov2_protein_counter.values()), align='center')
# Out:
# <BarContainer object of 20 artists>

# %%
plt.title('DNA Similarity')
plt.bar(X,Y)
# Out:
# <BarContainer object of 3 artists>

# %%
def getMostFreqMolecules(x):
    covid_acids = []
    covid_mole_struc = []

    for p in x:
        try:
            acid = amino_acids_mapping[p]

            # create a new molecule
            molecule = new_client.molecule
            molecule_chembl_id = molecule.search(acid)[0]['molecule_chembl_id']

            res = molecule.get(molecule_chembl_id)
            # return smile format molecular structure
            smileStruct = res['molecule_structures']['canonical_smiles']

            m = Chem.MolFromSmiles(smileStruct)
            m = Chem.AddHs(m)
            
            covid_acids.append(acid)
            covid_mole_struc.append(m)
        except:
            print('err')
            
    return covid_acids, covid_mole_struc

# %%
# Get the most frequent molecules found in covid19
covid_acids, covid_mole_struc = getMostFreqMolecules(cov2_protein_highest)

# %%
print('Get the most frequent molecules found in covid19')
for i in range(len(covid_acids)):
    print(f'{i}: {covid_acids[i]}')
# Out:
# Get the most frequent molecules found in covid19
# 0: Leu
# 1: Ser
# 2: Thr
# 3: Val

# %%
Draw.MolsToGridImage(covid_mole_struc, molsPerRow=2, maxMols=50, subImgSize=(400,400))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=800x800 at 0x7FDD1638B240>
